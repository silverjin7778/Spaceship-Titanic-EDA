# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('../')
os.getcwd()
# Out:
# 'c:\\Users\\samsung\\Documents\\workspace'

# %%
os.listdir()
# Out:
# ['data_description.txt',
#  'Housing.csv',
#  'phone_data.csv',
#  'sample_submission.csv',
#  'test.csv',
#  'test.ipynb',
#  'train.csv']

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df_data = pd.read_csv(data_url, sep = '\s+', header = None)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\samsung\AppData\Local\Temp\ipykernel_25752\2137632369.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df_data = pd.read_csv(data_url, sep = '\s+', header = None)

# %%
df_data.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','RTRATIO','B','LSTAT','MEDV']
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    RTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df_data['weight_0'] = 1
del df_data['MEDV']
#df_data = df_data.drop('MEDV', axis = 1)
df_data.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  RTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296.0     15.3
#
#        B  LSTAT  weight_0
# 0  396.9   4.98         1

# %%
df_matrix = df_data.values #매트릭스 데이터로 변환
type(df_matrix)
# Out:
# numpy.ndarray

# %%
df_data.groupby('RAD').get_group(1)
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.5380  6.575  65.2  4.0900    1  296.0
# 193  0.02187  60.0   2.93     0  0.4010  6.800   9.9  6.2196    1  265.0
# 194  0.01439  60.0   2.93     0  0.4010  6.604  18.8  6.2196    1  265.0
# 254  0.04819  80.0   3.64     0  0.3920  6.108  32.0  9.2203    1  315.0
# 255  0.03548  80.0   3.64     0  0.3920  5.876  19.1  9.2203    1  315.0
# 283  0.01501  90.0   1.21     1  0.4010  7.923  24.8  5.8850    1  198.0
# 284  0.00906  90.0   2.97     0  0.4000  7.088  20.8  7.3073    1  285.0
# 285  0.01096  55.0   2.25     0  0.3890  6.453  31.9  7.3073    1  300.0
# 286  0.01965  80.0   1.76     0  0.3850  6.230  31.5  9.0892    1  241.0
# 331  0.05023  35.0   6.06     0  0.4379  5.706  28.4  6.6407    1  304.0
# 332  0.03466  35.0   6.06     0  0.4379  6.031  23.3  6.6407    1  304.0
# 341  0.01301  35.0   1.52     0  0.4420  7.241  49.3  7.0379    1  284.0
# ...
